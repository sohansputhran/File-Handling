# %%
import os
import shutil
import numpy as np
import pandas as pd

# %%
directory = 'E:\Sonu\Pics\Irpu'

# %%
for filename in os.listdir(directory):
    if filename.endswith(".NEF"): 
        path = os.path.join(directory, "Unwanted Files")
        if not os.path.exists(path):
            os.makedirs(path)
        print(os.path.join(directory, filename))
# Out:
# E:\Sonu\Pics\Irpu\DSC_7261.NEF
# E:\Sonu\Pics\Irpu\DSC_7262.NEF
# E:\Sonu\Pics\Irpu\DSC_7264.NEF
# E:\Sonu\Pics\Irpu\DSC_7266.NEF
# E:\Sonu\Pics\Irpu\DSC_7269.NEF
# E:\Sonu\Pics\Irpu\DSC_7270.NEF
# E:\Sonu\Pics\Irpu\DSC_7271.NEF
# E:\Sonu\Pics\Irpu\DSC_7272.NEF
# E:\Sonu\Pics\Irpu\DSC_7273.NEF
# E:\Sonu\Pics\Irpu\DSC_7274.NEF
# E:\Sonu\Pics\Irpu\DSC_7275.NEF
# E:\Sonu\Pics\Irpu\DSC_7276.NEF
# E:\Sonu\Pics\Irpu\DSC_7277.NEF
# E:\Sonu\Pics\Irpu\DSC_7278.NEF
# E:\Sonu\Pics\Irpu\DSC_7279.NEF
# E:\Sonu\Pics\Irpu\DSC_7280.NEF
# E:\Sonu\Pics\Irpu\DSC_7281.NEF
# E:\Sonu\Pics\Irpu\DSC_7282.NEF
# E:\Sonu\Pics\Irpu\DSC_7283.NEF
# E:\Sonu\Pics\Irpu\DSC_7284.NEF
# E:\Sonu\Pics\Irpu\DSC_7285.NEF
# E:\Sonu\Pics\Irpu\DSC_7286.NEF
# E:\Sonu\Pics\Irpu\DSC_7287.NEF
# E:\Sonu\Pics\Irpu\DSC_7288.NEF
# E:\Sonu\Pics\Irpu\DSC_7289.NEF
# E:\Sonu\Pics\Irpu\DSC_7290.NEF
# E:\Sonu\Pics\Irpu\DSC_7291.NEF
# E:\Sonu\Pics\Irpu\DSC_7293.NEF
# E:\Sonu\Pics\Irpu\DSC_7294.NEF
# E:\Sonu\Pics\Irpu\DSC_7295.NEF
# ...
